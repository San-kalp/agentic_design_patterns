# %%
import os 
import asyncio
from typing import Optional
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import Runnable, RunnableParallel, RunnablePassthrough

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
llm = ChatOpenAI(
    model = "gpt-4o-mini",
    temperature= 0, 
    top_p = 0.75, 
    frequency_penalty= 1.2
)

# %%
#Defining three independent chains 
summarize_chain : Runnable = (
    ChatPromptTemplate.from_messages(
        [
            ("system","Summarize the following topic"),
            ("user","{topic}")
        ]
    ) | llm | StrOutputParser()
)

question_chain : Runnable = (
    ChatPromptTemplate.from_messages(
        [
            ("system" , "Generate three interesting questions about the following topic:"),
            ("user","{topic}")
        ]
    ) | llm | StrOutputParser()
)

terms_chain : Runnable = (
    ChatPromptTemplate.from_messages(
        [
            ("system","Find 5-10 key terms from the following topic seperated by commas:"),
            ("user","{topic}")
        ]
    ) | llm | StrOutputParser()
)

# %%
map_chain = RunnableParallel(
    {
        "summary" : summarize_chain,
        "questions" : question_chain,
        "key_terms" : terms_chain,
        "topic" : RunnablePassthrough()
    }
)

# %%
prompt = ChatPromptTemplate.from_messages([
    ("system","""
     Based on the following information :
     Summary : {summary}
     Related Questions : {questions}
     Key terms : {key_terms}
     
     Synthesize a comprehensive answer.
     """),
    ("user", "Original topic : {topic}")
])

# %%
parallel_chain = map_chain | prompt | llm | StrOutputParser()

# %%
async def run_parallel(topic:str):
    response = await parallel_chain.ainvoke(topic)
    print(response)

# %%
await run_parallel("The history of Agentic AI")
# Out:
# The history of Agentic AI is a fascinating journey that reflects the evolution of artificial intelligence (AI) from its nascent stages to the sophisticated systems we see today. Agentic AI refers to autonomous systems capable of making decisions and acting independently in various contexts, which has significant implications for technology and society.
#
# **Early Developments (Mid-20th Century)**
# The roots of Agentic AI can be traced back to the mid-20th century when researchers began exploring foundational concepts such as machine learning, problem-solving, and automated reasoning. During this period, early algorithms were developed that allowed machines to learn from data—laying the groundwork for future advancements.
#
# **Advancements in Learning Algorithms (1960s - 1970s)**
# In the 1960s and 1970s, significant progress was made with algorithms that enabled machines to adapt their behavior based on experience. This era marked a shift towards more complex models capable of learning from interactions with their environment—a crucial aspect of agentic capabilities.
#
# **Neural Networks Revolution (1980s)**
# The introduction of neural networks in the 1980s represented a pivotal milestone in AI development. These models facilitated advanced pattern recognition and decision-making processes by mimicking human cognitive functions. The ability for machines to process vast amounts of data through layered architectures opened new avenues for creating intelligent agents.
#
# **Reinforcement Learning & Multi-Agent Systems (Late 1990s - Early 2000s)**
# As computing power continued to grow, so did innovations like reinforcement learning and multi-agent systems during the late 1990s and early 2000s. These technologies allowed agents not only to learn but also interact dynamically with other agents or environments—enhancing their autonomy further.
#
# **Recent Breakthroughs: Deep Learning & NLP (2010-Present)**
# In recent years, breakthroughs in deep learning techniques have propelled Agentic AI into mainstream applications such as autonomous vehicles, virtual assistants like Siri or Alexa, and even complex decision-making tools used across industries. Natural language processing has enabled these systems not just to perform tasks but also engage meaningfully with humans—a critical aspect given our increasing reliance on technology.
#
# **Ethical Considerations & Societal Impact**
# However, this rapid evolution raises pressing ethical concerns regarding accountability for decisions made by these intelligent agents; issues surrounding safety protocols; potential biases embedded within algorithms; control over autonomous actions; privacy implications; among others have emerged as focal points within discussions about responsible development practices in this field.
#
# Frameworks addressing these risks are being developed alongside technological advancements—such as ethical guidelines proposed by organizations focusing on transparency around algorithm design or regulatory measures aimed at ensuring safe deployment practices across sectors utilizing agentic capabilities effectively while minimizing harm potentiality associated therein.
#
# Overall—the history of Agentic AI illustrates an ongoing interplay between technological innovation driven by historical milestones—and societal values reflected through public perception shaping regulatory approaches toward increasingly autonomous systems we encounter today.

# %% [markdown]
# ## Deep Parallel Research

# %%
#There are three topics that needs to be researched in parallel
# 1. Renewable Energy
# 2. EVs
# 3. Carbon Capture

#So let us create three chains for this.
researcher_chain_1 : Runnable  = (
    ChatPromptTemplate.from_messages([
        ("system","You are an AI researcher specialised in energy. Topic = {topic}"),
        ("user","Research the latest advancement in 'renewable energy sources' and summarize your findings in 1-2 sentences.")
    ]) | llm | StrOutputParser()
)

#researcher_chain_2 - EVs
researcher_chain_2 : Runnable = (
    ChatPromptTemplate.from_messages([
        ("system","You are an AI researcher specialised in transportation. Topic = {topic}"),
        ("user","Research the latest advancement in 'electric vehicles (EVs)' and summarize your findings in 1-2 sentences.")
    ]) | llm | StrOutputParser()
)

#researcher_chain_3 - Carbon capture
researcher_chain_3 : Runnable = (
    ChatPromptTemplate.from_messages([
        ("system","You are an AI researcher specialised in climate technology. Topic = {topic}"),
        ("user","Research the latest advancement in 'carbon capture technology' and summarize your findings in 1-2 sentences.")
    ]) | llm | StrOutputParser()
)

# %%
map_chain = RunnableParallel({
    "latest_advancement_energy" : researcher_chain_1,
    "latest_advancement_ev" : researcher_chain_2,
    "latest_advancement_climate" : researcher_chain_3,
    "topic" : RunnablePassthrough()
})

# %%
combined_research_prompt = ChatPromptTemplate.from_messages([
    ("system","You are an AI assistant responsible for combining research findings into a structured report. Your primary task is to synthesize the following research summairies."),
    ("user", """
     Topic : {topic}
     Latest Advancement in energy : {latest_advancement_energy},
     
     Latest Advancement in EV : {latest_advancement_ev},
     
     Latest Advancement in climate : {latest_advancement_climate},
     """)
])

# %%
parallel_research_chain = map_chain | combined_research_prompt | llm | StrOutputParser()

# %%
async def run_parallel_research(topic) :
    response = await parallel_research_chain.ainvoke(topic)
    print(response)

# %%
await run_parallel_research("Green Energy")
# Out:
# # Report on Recent Advancements in Green Energy
#
# ## Introduction
# The transition to green energy is critical for addressing climate change and promoting sustainable development. This report synthesizes the latest advancements in renewable energy sources, electric vehicles (EVs), and carbon capture technologies, highlighting innovations that enhance efficiency, reliability, and integration into existing systems.
#
# ## 1. Advancements in Renewable Energy Sources
# Recent developments in renewable energy have focused on improving efficiency and maximizing resource utilization:
#
# - **Solar Energy**: The introduction of perovskite-silicon tandem solar cells has marked a significant milestone, achieving efficiencies exceeding 30%. This advancement not only enhances the performance of solar panels but also contributes to reducing the cost per watt of solar electricity.
#
# - **Wind Energy**: Floating wind farms are emerging as a transformative solution for harnessing wind power. These installations allow for greater energy capture while minimizing land use conflicts by being situated offshore or in less populated areas.
#
# - **Energy Storage Technologies**: Innovations such as solid-state batteries offer improved safety and higher energy density compared to traditional lithium-ion batteries. Additionally, advanced pumped hydro systems are being developed to enhance the reliability of renewable sources by providing effective storage solutions that can balance supply with demand.
#
# ## 2. Advancements in Electric Vehicles (EVs)
# The electric vehicle sector is experiencing rapid technological advancements aimed at enhancing performance and sustainability:
#
# - **Battery Technology**: Solid-state batteries are at the forefront of EV innovation due to their potential for faster charging times, increased range through higher energy density, and enhanced safety features over conventional battery technologies.
#
# - **Autonomous Driving Systems**: Automakers are increasingly integrating sophisticated AI systems into EVs which optimize driving efficiency while enhancing autonomous capabilities. These advancements contribute not only to user convenience but also promote safer driving practices.
#
# ## 3. Advancements in Carbon Capture Technology
# Carbon capture technology is evolving rapidly with new methods designed to improve CO2 absorption rates while reducing overall energy consumption:
#
# - **Direct Air Capture Systems**: Recent innovations include more efficient direct air capture technologies utilizing advanced sorbents that significantly increase CO2 absorption rates without requiring excessive amounts of energy.
#
# - **Integration with Renewable Sources**: Researchers are exploring synergies between carbon capture processes and renewable energies—creating pathways for capturing CO2 from ambient air using clean power sources. This approach opens up possibilities for producing synthetic fuels or building materials from captured carbon dioxide.
#
# ## Conclusion
# The recent advancements across various sectors within green energy demonstrate a concerted effort towards creating more efficient, reliable, and sustainable solutions. From improvements in solar panel technology to breakthroughs in battery design for electric vehicles and innovative approaches to carbon capture—these developments collectively contribute towards mitigating climate change impacts while fostering an environmentally friendly future. Continued investment and research will be essential as we strive toward global sustainability goals.
